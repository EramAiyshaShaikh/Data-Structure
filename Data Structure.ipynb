# %% [markdown]
# # THEORY QUESTIONS

# %% [markdown]
# **1. What are data structures, and why are they important?**
# - Data Structures are a way of organizing data so that it can be accessed more efficiently depending upon the situation. Data Structures are fundamentals of any programming language around which a program is built. Python helps to learn the fundamental of these data structures in a simpler way as compared to other programming languages.
# - Data Structures are important because they provide efficiency,organization and management,code readability,memory management
# - Python offers a variety of built-in data structures like lists, tuples, sets, and dictionaries, each suited for different use cases. Additionally, more complex data structures like stacks, queues, trees, and graphs can be implemented using Python's object-oriented features. Understanding and effectively utilizing these data structures is fundamental for writing robust, scalable, and efficient Python applications.
#
# **2. Explain the difference between mutable and immutable data types with examples**
# - Mutable: Mutable is when something is changeable or has the ability to change. In Python, ‘mutable’ is the ability of objects to change their values. These are often the objects that store a collection of data.
#   - Example:
#     ##### dictionary is mutable
#     my_dict = {"name": "Ram", "age": 25}
#     new_dict = my_dict
#     new_dict["age"] = 37
#     print(my_dict)
#     print(new_dict)
#
#     OUTPUT:
#     {'name': 'Ram', 'age': 37}
#     {'name': 'Ram', 'age': 37}
# - Immutable: Immutable is the when no change is possible over time. In Python, if the value of an object cannot be changed over time, then it is known as immutable. Once created, the value of these objects is permanent.
#   - Example: Since strings are immutable an error message will display
#     ##### strings are immutable
#     message = "Welcome to GeeksforGeeks"
#     message[0] = 'p'
#     print(message)
#
#     OUTPUT:
#     message[0] = 'p'
#     TypeError: 'str' object does not support item assignment
#
# **3. What are the main differences between lists and tuples in Python**
# - In Python, lists and tuples both store collections of data, but differ in mutability
# - Lists can be modified, meaning their elements can be changed, added or removed after creation.
#   - Example: a = [1, 2, 4, 4, 3, 3, 3, 6, 5]
#     ##### Modifying an element in the list 'a'
#     a[3] = 77
#     print(a)
#
#     OUTPUT:
#     [1, 2, 4, 77, 3, 3, 3, 6, 5]
# - Tuples cannot be modified after creation. Any attempt to change an element will result in an error.
#   - Example: b = (0, 1, 2, 3)
#     ##### Attempting to modify a tuple
#     b[0] = 4
#     print(b)
#
#     OUTPUT:
#     b[0] = 4
#     TypeError: 'tuple' object does not support item assignment
#
# **4. Describe how dictionaries store data**
# - Python dictionary is a data structure that stores the value in key: value pairs. Values in a dictionary can be of any data type and can be duplicated, whereas keys can't be repeated and must be immutable.
#   - Example: Here, The data is stored in key:value pairs in dictionaries, which makes it easier to find values.
#
#     d = {1: 'Geeks', 2: 'For', 3: 'Geeks'}
#     print(d)
#
#     OUTPUT:
#     {1: 'Geeks', 2: 'For', 3: 'Geeks'}
#
# **5. Why might you use a set instead of a list in Python**
# - In Python, both sets and lists are used to store collections of elements but they have key differences that make them suitable for different use cases. The main difference is that lists are ordered, meaning the order of elements is preserved and they can be accessed by their index while sets are unordered meaning they do not maintain the order of elements and automatically ensure all elements are unique.
#   - Example:
#     ##### Creating a set
#     s1 = {1, 2, 3, 4}
#     s2 = set([4, 5, 6, 7])
#
#     print(s1)
#     print(s2)
#
#     OUTPUT:
#     {1, 2, 3, 4}
#     {4, 5, 6, 7}
# - Uniqueness of Elements in Seta:
#   Sets inherently store only unique elements. If you need a collection where duplicate values are not allowed, a set automatically handles this by preventing the addition of identical items. Lists, conversely, allow duplicates.
#
# **6. What is a string in Python, and how is it different from a list**
# - A string is a sequence of characters. Python treats anything inside quotes as a string. This includes letters, numbers, and symbols. Python has no character data type so single character is a string of length 1.
#   - Example:
#     Strings can be created using either single (') or double (") quotes.
#     s1 = 'GfG'
#     s2 = "GfG"
#     print(s1)
#     print(s2)
#
#     OUTPUT:
#     GfG
#     GfG
# - Mutable vs. Immutable: A list is mutable, meaning you can modify its elements after it is created. On the other hand, a string is immutable, which means you cannot change its characters once it is created. Instead, you need to create a new string with the desired modifications.
#   - Example:
#     my_list = [1, 2, 3, 4]
#     my_string = "Hello, World!"
#     ##### Modifying a list
#     my_list[2] = 5
#     print(my_list)
#     ##### Output: [1, 2, 5, 4]
#     ##### Attempting to modify a string will result in an error
#     my_string[2] = 'x'
#     ##### Raises TypeError: 'str' object does not support item assignment
#
# **7. How do tuples ensure data integrity in Python**
# - Tuples are an essential data structure in Python, representing an immutable, ordered collection of elements. They are similar to lists but with a key difference: once a tuple is created, its contents cannot be changed. This immutability makes tuples a reliable choice for storing fixed collections of data.
# - Tuples are commonly used when you want to group related pieces of information together. They ensure that the group of information stays unchanged throughout your program.
# - Tuples are faster than Lists in Python in execution and are used based on its requirements where we need immutable and fast execution. The immutability of tuple ensures data integrity.
#   - Example: The information cannot be changed
#
#     b = (0, 1, 2, 3)
#     ##### Attempting to modify a tuple
#     b[0] = 4
#     print(b)
#
#     OUTPUT:
#     b[0] = 4
#     TypeError: 'tuple' object does not support item assignment
#
# **8. What is a hash table, and how does it relate to dictionaries in Python**
# - A Hash Table in Python utilizes an array as a medium of storage and uses the hash method to create an index where an element is to be searched from or needs to be inserted. In other words, a Hash Table in Python is a data structure which stores data by using a pair of values and keys
# - In Python, the Dictionary data types represent the implementation of hash tables. The Keys in the dictionary are hashable–they are generated by a hash function which generates a unique result for each unique value supplied to the hash function.
# - Python has a built-in function to generate the hash of an object, the hash() function. This function takes an object as input and returns the hash as an integer.
# - Since dictionaries are built on top of hash tables, you can only insert an element if its key is hashable. If the key of your element is not hashable (like a list, for example), the interpreter throws an TypeError exception:
#   - Example:
#
#     my_list = ["Giri", "Mamedyarov"]
#     chess_players[my_list] = 2764
#
#     OUTPUT:
#     TypeError: unhashable type: 'list'
#
# **9. Can lists contain different data types in Python**
# -  In Python, lists can contain heterogeneous data types and objects. For instance, integers, strings, and even functions can be stored within the same list. Different elements of a list can be accessed by integer indices where the first element of a list has the index of 0. This property derives from the fact that in Python, lists are ordered, which means they retain the order in which you insert the elements into the list.
#   - Example:
#
#     list1 = ["apple", "banana", "cherry"]
#     list2 = [1, 5, 7, 9, 3]
#     list3 = [True, False, False]
#
#     print(list1)
#     print(list2)
#     print(list3)
#
#     OUTPUT:
#     ['apple', 'banana', 'cherry']
#     [1, 5, 7, 9, 3]
#     [True, False, False]
#
#
# **10. Explain why strings are immutable in Python**
# - Strings in Python are "immutable" which means they can not be changed after they are created. Some other immutable data types are integers, float, boolean, etc.
#
# - The immutability of Python string is very useful as it helps in hashing, performance optimization, safety, ease of use, etc.
#   - Example:
#
#     name_1 = "Aarun"
#     name_1[0] = 'T'
#
#     OUTPUT: TypeError: 'str' object does not support item assignment
# - Immutability ensures one reference does not change the value for others pointing to the same string. Security: Strings are used for sensitive data like usernames and passwords. Immutability prevents attackers from altering the values.
#
# **11. What advantages do dictionaries offer over lists for certain tasks**
# - Lists and Dictionaries in Python are inbuilt data structures that are used to store data. Lists are linear in nature whereas dictionaries stored the data in key-value pairs.
# - A Python dictionary is a data structure that stores the value in key: value pairs. Values in a dictionary can be of any data type and can be duplicated, whereas keys can't be repeated and must be immutable.
#   - Example:
#
#     ##### Creating a Dictionary with Integer Keys
#     Dict = {1: 'John', 2: 'Peter', 3: 'Nolan'}
#     print("Dictionary with the use of Integer Keys: ", Dict)
#     ##### Accessing particular elements
#     print(Dict[1])
#     print(Dict[2])
#     ##### Creating a Dictionary with Mixed keys
#     Dict = {'Name': 'John', 1: [1, 2, 3, 4]}
#     print("\nDictionary with the use of Mixed Keys: ", Dict)
#     ##### Accessing particular elements
#     print(Dict['Name'])
#     print(Dict[1])
#
#     OUTPUT:
#     Dictionary with the use of Integer Keys:  {1: 'John', 2: 'Peter', 3: 'Nolan'}
#     John
#     Peter
#     Dictionary with the use of Mixed Keys:  {'Name': 'John', 1: [1, 2, 3, 4]}
#     John
#     [1, 2, 3, 4]
# - Dictionaries provide faster lookups compared to lists when searching by key, as they have an average complexity of O(1), while lists require O(n) in the worst case.
# - For large-scale searches and deletions, dictionaries outperform lists.
#
# **12. Describe a scenario where using a tuple would be preferable over a list**
# - In Python, tuples are generally preferred over lists in the following scenarios:
#   - Immutability: Tuples are immutable, meaning their contents cannot be changed after creation. This makes them suitable for representing fixed collections of items where you want to ensure that the data remains constant. For example, using a tuple to represent coordinates (x, y) ensures that these values cannot be altered accidentally.
#   - Performance: Tuples can be more memory-efficient and faster than lists for certain operations since they have a smaller memory overhead due to their immutability. If you need a collection of items that doesn't change, using a tuple can lead to better performance.
#   - Hashability: Tuples can be used as keys in dictionaries or elements in sets because they are hashable (as long as their elements are hashable). Lists, on the other hand, cannot be used in these contexts due to their mutability.
#   - Semantic Meaning: When the data represents a fixed structure or a record, tuples can provide clearer semantics. For example, using a tuple to represent a database record (like (id, name, age)) can convey that the data structure is intended to be a fixed, non-changing set of values.
#   - Multiple Return Values: Tuples are commonly used to return multiple values from a function. This makes it clear that the function is returning a fixed number of related values.
#   - Example:
#     ##### Using a tuple to represent a 2D point
#     point = (3, 5)
#     ##### Attempting to change a value (will raise an error)
#     ##### point[0] = 10  # This would raise a TypeError
#     ##### Using a tuple as a dictionary key
#     point_dict = {point: "A point in 2D space"}
#     ##### Using a list for mutable collections
#     mutable_list = [1, 2, 3]
#     mutable_list.append(4)  # Lists can be changed
#
# **13. How do sets handle duplicate values in Python**
# - Python sets fundamentally do not allow duplicate values. They are designed to store only unique elements.
# - When attempting to add a duplicate element to a set, the set simply ignores the addition; it does not raise an error, and the existing element remains in the set without any change or addition of the duplicate.
# - This characteristic makes sets highly useful for operations requiring unique collections of items, such as removing duplicates from a list or performing mathematical set operations like union, intersection, and difference.
#   - Example:
#     my_set = {1, 2, 3, 2, 4}
#     print(my_set)
#
#     OUTPUT:
#     {1, 2, 3, 4}
#
# **14. How does the “in” keyword work differently for lists and dictionaries**
# - The in and not in operator works on dictionaries; it tells you whether something appears or not as a key in the dictionary. It returns two values True or False.
# - The in operator uses different algorithms for lists and dictionaries. For lists, it uses a search algorithm. As the list gets longer, the search time gets longer in direct proportion. For dictionaries, Python uses an algorithm called a hashtable that has a remarkable property: the in operator takes about the same amount of time no matter how many items there are in a dictionary.
# - The in operation for the dictionary tests on keys. The key of the dictionary is a unique value as well as the set, and the execution time is about the same as for sets. On the other hand, dictionary values can be duplicated like a list
#
# **15. Can you modify the elements of a tuple? Explain why or why not**
# - Tuples are unchangeable, meaning that you cannot change, add, or remove items once the tuple is created.
# - But there are some workarounds. You can convert the tuple into a list, change the list, and convert the list back into a tuple.
#   - Example:
#     x = ("apple", "banana", "cherry")
#     y = list(x)
#     y[1] = "kiwi"
#     x = tuple(y)
#     print(x)
#
#     OUTPUT:
#     ("apple", "kiwi", "cherry")
#
#
# **16. What is a nested dictionary, and give an example of its use case**
# - In Python, a nested dictionary is a dictionary inside a dictionary. It's a collection of dictionaries into one single dictionary.
#   - Example:
#     nested_dict = { 'dictA': {'key_1': 'value_1'},
#                     'dictB': {'key_2': 'value_2'}}
# - Use Cases:
#   - Storing complex data:
#     Nested dictionaries are ideal for representing data with multiple layers of organization, such as employee records, product catalogs, or even game data.
#   - Representing hierarchical relationships:
#     The nested structure allows you to easily model parent-child relationships or categories and subcategories.
#   - JSON data:
#     Nested dictionaries map naturally to the structure of JSON data, making them useful when working with APIs or web services that return JSON responses.
#   - Configuration files:
#     You can represent complex configuration settings using nested dictionaries, where keys represent different sections or modules and values are dictionaries containing specific settings.
#
# **17. Describe the time complexity of accessing elements in a dictionary**
# - Python dictionaries provide a fast and efficient way to store and retrieve data using key value pair so understanding the time complexities of dictionary operations is very important for optimizing performance in our programs.
# - The time complexity of retrieving a value by its key in a dictionary is O(1). This is because dictionaries use a hash table internally which allows constant time lookup.
#   - Example:
#     ##### Create a dictionary
#     dict = {'a': 1, 'b': 2, 'c': 3}
#     ##### Access value by key
#     val = dict['b']
#     print(val)
#
# **18. In what situations are lists preferred over dictionaries**
# - If you need an ordered collection, like a sequence of user actions, lists are your go-to. On the other hand, when you need quick look-ups, like mapping usernames to user data, dictionaries are invaluable.
# - Use a list when:
#   1. Order Matters: You need to maintain the order of elements, as lists are ordered collections.
#   2. Indexed Access: You want to access elements by their position (index) in the collection.
#   3. Iterating: You need to frequently iterate over a sequence of items.
#   4. Homogeneous Data: You are storing a collection of similar items (e.g., numbers, strings).
#
# **19. Why are dictionaries considered unordered, and how does that affect data  retrieval**
# - Dictionary is a data structure which is a important value structure, optimized for fast storage and recovery based on key.
# - In python, dictionaries are un-ordered because Python dictionaries are not intended to be in order, as simple as that. If we want to collect a set of objects in order, we have only one choice of accessing them: through index.
#
# **20.  Explain the difference between a list and a dictionary in terms of data retrieval.**
# - A list is an ordered collection of items, whereas a dictionary is an unordered data collection in a key: value pair. Elements from the list can be accessed using the index, while the elements of the dictionary can be accessed using keys.
# - The list allows duplicate items, while the dictionary does not allow any duplicate keys.
# - A list can store any data type. In contrast, keys in the dictionary can be of any immutable data type, and values can be of any data type.
# - Lists perform faster for ordered operations like sorting, while dictionaries perform faster for lookup operations.

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# #PRACTICAL QUESTIONS

# %%
### 1. Write a code to create a string with your name and print it
my_name = input('Enter your name: ')
print('My name is:',my_name)
# Out:
# Enter your name: Eram Aiysha
# My name is: Eram Aiysha

# %%
### 2. Write a code to find the length of the string "Hello World"
my_string = 'Hello World'
length = len(my_string)
print("The length of the string 'Hello World' is:",length)
# Out:
# The length of the string 'Hello World' is: 11

# %%
### 3.Write a code to slice the first 3 characters from the string "Python Programming"
my_string = 'Python Programming'
after_slicing = my_string[0:3]
print('The first 3 characters after slicing is:',after_slicing)
# Out:
# The first 3 characters after slicing is: Pyt

# %%
### 4.Write a code to convert the string "hello" to uppercase
first_string = 'hello'
first_string = first_string.upper()
print('The string after converting it to upper case is:',first_string)
# Out:
# The string after converting it to upper case is: HELLO

# %%
### 5.Write a code to replace the word "apple" with "orange" in the string "I like apple"
my_string = 'I like apple'
print('The given string is:',my_string)
my_string = my_string.replace('apple','orange')
print("The string after replacing the word 'apple' with 'orange' is:",my_string)
# Out:
# The given string is: I like apple
# The string after replacing the word 'apple' with 'orange' is: I like orange

# %%
### 6. Write a code to create a list with numbers 1 to 5 and print it
my_list=[1,2,3,4,5]
my_list = my_list[:]
print('The list contains:',my_list)
# Out:
# The list contains: [1, 2, 3, 4, 5]

# %%
### 7.Write a code to append the number 10 to the list [1, 2, 3, 4]
my_list = [1,2,3,4]
print('The list before appending a number is:',my_list)
my_list.append(10)
print('The list after appending a number is:',my_list)
# Out:
# The list before appending a number is: [1, 2, 3, 4]
# The list after appending a number is: [1, 2, 3, 4, 10]

# %%
### 8. Write a code to remove the number 3 from the list [1, 2, 3, 4, 5]
my_list = [1,2,3,4,5]
print('The list before removing a number is:',my_list)
my_list.remove(3)
print('The list after removing a number is:',my_list)
# Out:
# The list before removing a number is: [1, 2, 3, 4, 5]
# The list after removing a number is: [1, 2, 4, 5]

# %%
### 9.Write a code to access the second element in the list ['a', 'b', 'c', 'd']
my_list = ['a','b','c','d']
second_element = my_list[1]
print('The second element in the list is:',second_element)
# Out:
# The second element in the list is: b

# %%
### 10.Write a code to reverse the list [10, 20, 30, 40, 50].
my_list = [10,20,30,40,50]
reversed_list = my_list[::-1]
print('The revered list is:',reversed_list)
# Out:
# The revered list is: [50, 40, 30, 20, 10]

# %%
### 11.Write a code to create a tuple with the elements 100, 200, 300 and print it
my_tuple = (100,200,300)
print('The tuple contains:',my_tuple)

###OR

my_tuple[:]
# Out:
# The tuple contains: (100, 200, 300)
# (100, 200, 300)

# %%
### 12.Write a code to access the second-to-last element of the tuple ('red', 'green', 'blue', 'yellow')
my_tuple = ('red','green','blue','yellow')
second_to_last_element = my_tuple[-2]
print('The second-to-last element in the tuple is:',second_to_last_element)
# Out:
# The second-to-last element in the tuple is: blue

# %%
### 13.Write a code to find the minimum number in the tuple (10, 20, 5, 15)
my_tuple = (10,20,5,15)
min_num = min(my_tuple)
print('The mininum number in the tuple is:',min_num)
# Out:
# The mininum number in the tuple is: 5

# %%
### 14.Write a code to find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit')
my_tuple = ('dog','cat','rabbit')
cat_index = my_tuple.index('cat')
print("The index of the element 'cat' is:",cat_index)
# Out:
# The index of the element 'cat' is: 1

# %%
### 15.Write a code to create a tuple containing three different fruits and check if "kiwi" is in it
my_fruits = input('Enter three different fruits:')
print('The entered fruits are:',my_fruits)

if 'kiwi' in my_fruits:
  print('Kiwi is in the tuple')
else:
  print('Kiwi is not in the tuple')
# Out:
# Enter three different fruits:apple,banana,kiwi
# The entered fruits are: apple,banana,kiwi
# Kiwi is in the tuple

# %%
### 16.Write a code to create a set with the elements 'a', 'b', 'c' and print it.
my_set = {'a','b','c'}
print('The set is:',my_set)
# Out:
# The set is: {'b', 'a', 'c'}

# %%
### 17. Write a code to clear all elements from the set {1, 2, 3, 4, 5}.
my_set = {1,2,3,4,5}
print('The set before clearing all the element:',my_set)
my_set.clear()
print('The set after clearing all the element:',my_set)
# Out:
# The set before clearing all the element: {1, 2, 3, 4, 5}
# The set after clearing all the element: set()

# %%
### 18.Write a code to remove the element 4 from the set {1, 2, 3, 4}.
my_set = {1,2,3,4}
print('The set before removing the element:',my_set)
my_set.remove(4)
print('The set after element 4 is removed:',my_set)
# Out:
# The set before removing the element: {1, 2, 3, 4}
# The set after element 4 is removed: {1, 2, 3}

# %%
### 19. Write a code to find the union of two sets {1, 2, 3} and {3, 4, 5}.
first_set = {1,2,3}
second_set = {3,4,5}
union_set = first_set | second_set
print("The union of first set '{1,2,3}' and second set'{3,4,5}' is:",union_set)
# Out:
# The union of first set '{1,2,3}' and second set'{3,4,5}' is: {1, 2, 3, 4, 5}

# %%
### 20.Write a code to find the intersection of two sets {1, 2, 3} and {2, 3, 4}
first_set = {1,2,3}
second_set = {2,3,4}
intersection_set = first_set & second_set
print("The inetrsection of first set '{1,2,3}' and second set '{2,3,4}' is:",intersection_set)
# Out:
# The inetrsection of first set '{1,2,3}' and second set '{2,3,4}' is: {2, 3}

# %%
### 21.Write a code to create a dictionary with the keys "name", "age", and "city", and print it.
my_dict = {'name':'Peter','age':20,'city':'bangalore'}
print('The items in the dictionary is:',my_dict)
# Out:
# The items in the dictionary is: {'name': 'Peter', 'age': 20, 'city': 'bangalore'}

# %%
### 22. Write a code to add a new key-value pair "country": "USA" to the dictionary {'name': 'John', 'age': 25}.
my_dict = {'name': 'John', 'age':25}
print('The dictionary before adding an element:',my_dict)
my_dict['country'] = 'USA'
print('The dictionary after adding the element:',my_dict)
# Out:
# The dictionary before adding an element: {'name': 'John', 'age': 25}
# The dictionary after adding the element: {'name': 'John', 'age': 25, 'country': 'USA'}

# %%
### 23.Write a code to access the value associated with the key "name" in the dictionary {'name': 'Alice', 'age': 30}.
my_dict = {'name': 'Alice', 'age': 30}
name_value = my_dict['name']
print('The name in the dictionary is:',name_value)
# Out:
# The name in the dictionary is: Alice

# %%
### 24.Write a code to remove the key "age" from the dictionary {'name': 'Bob', 'age': 22, 'city': 'New York'}.
my_dict = {'name': 'Bob', 'age': 22, 'city': 'New York'}
print('The dictionary before removing an element:',my_dict)
my_dict.pop('age')
print('The dictionary after removing the element:',my_dict)
# Out:
# The dictionary before removing an element: {'name': 'Bob', 'age': 22, 'city': 'New York'}
# The dictionary after removing the element: {'name': 'Bob', 'city': 'New York'}

# %%
### 25.Write a code to check if the key "city" exists in the dictionary {'name': 'Alice', 'city': 'Paris'}
my_dict = {'name': 'Alice', 'city': 'Paris'}

if 'city' in my_dict.keys():
  print('The city',my_dict['city'],'exists in the dictionary')
else:
  print('The city is not present in the dictionary')
# Out:
# The city Paris exists in the dictionary

# %%
### 26.Write a code to create a list, a tuple, and a dictionary, and print them all.
my_list = ['Apple','Banana','Orange']
print('The list is:',my_list)

my_tuple = ('Cleaning','Cooking','Shopping')
print('The tuple is:',my_tuple)

my_dict = {'Name': 'John', 'Age': 30, 'Country': 'USA'}
print('The dictionary is:',my_dict)

###OR

user_list = input('Enter the elements in the list:')
my_list = list(user_list.split(','))
print('The list is:',my_list)

user_tuple = input('Enter the elements in the tuple:')
my_tuple = tuple(user_tuple.split(','))
print('The tuple is:',my_tuple)

user_dict = input('Enter the elements in the dictionary:')
new_dict = user_dict.split(',')
final_dict = {}

for item in new_dict:
 if ':' in item:
  key,value = item.split(':',1)
  final_dict[key.strip()] = value.strip()
 else:
    print(f"Skipping invalid input: {item}")

for key,value in final_dict.items():
 print(f'The dictionary has: {key}:{value}')
# Out:
# The list is: ['Apple', 'Banana', 'Orange']
# The tuple is: ('Cleaning', 'Cooking', 'Shopping')
# The dictionary is: {'Name': 'John', 'Age': 30, 'Country': 'USA'}
# Enter the elements in the list:a,b
# The list is: ['a', 'b']
# Enter the elements in the tuple:c,d
# The tuple is: ('c', 'd')
# Enter the elements in the dictionary:name:john,age:30
# The dictionary has: name:john
# The dictionary has: age:30

# %%
### 27.Write a code to create a list of 5 random numbers between 1 and 100, sort it in ascending order, and print the
###result.(replaced)
import random
random_list = [random.randint(1,100) for i in range(5)]
random_list.sort()
print(random_list)
# Out:
# [20, 40, 43, 47, 90]

# %%
### 28.Write a code to create a list with strings and print the element at the third index.
my_list = input('Enter the elements in the list:')
my_list = list(my_list.split(','))
print('The element at the third index is:',my_list[2])
# Out:
# Enter the elements in the list:apple,banana,orange
# The element at the third index is: orange

# %%
### 29.Write a code to combine two dictionaries into one and print the result
my_dict1 = {'name':'John','Age':30}
my_dict2 = {'City':'New York','Country':'USA'}
print('Before updating, the dictionary is:',my_dict1, ',',my_dict2)
my_dict1.update(my_dict2)
print('The updated dictionary is:',my_dict1)
# Out:
# Before updating, the dictionary is: {'name': 'John', 'Age': 30} , {'City': 'New York', 'Country': 'USA'}
# The updated dictionary is: {'name': 'John', 'Age': 30, 'City': 'New York', 'Country': 'USA'}

# %%
### 30.Write a code to convert a list of strings into a set.
my_list = input('Enter the elements in the list:')
my_list = list(my_list.split(','))
print('The list is:',my_list)

my_set = set(my_list)
print('The converted set is:',my_set)
# Out:
# Enter the elements in the list:apple,banana,orange
# The list is: ['apple', 'banana', 'orange']
# The converted set is: {'orange', 'apple', 'banana'}
